# %%
from fmcw_data_processor import Fmcw_Data_Processor

# %%
# path = "D:\syndicate_tests_velocity_detection_1\FMCW_Radar\FMCW_Radar.raw"
radar_config={"chirps": 1, "tx": 3, "rx": 4, "samples" : 256}
#path = "D:\syndicate_tests_hw_trigger_post_R_4\FMCW_Radar\FMCW_Radar.raw"
path = "D:\BP_RF_CAM\FMCW_Radar\FMCW_Radar.raw"
data = Fmcw_Data_Processor(path, radar_config=radar_config)
# Out:
# Count: 12434
# True Packet Count: 12397

# %%
print(data.get_data().shape)
# Out:
# (1468, 3, 4, 256)

# %%
print(data.get_range_doppler_array().shape)
# Out:
# (1468, 3, 4, 256)

# %%
print(data.get_angle_array().shape)
# Out:
# (1468, 3, 128, 256)

# %%
data.generate_image_angle_range()

# %%
data.generate_image_velocity_range()

# %%
data.generate_image_angle_velocity()
